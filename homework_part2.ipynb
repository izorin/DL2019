# %% [markdown]
# # Homework 2, *part 2* (60 points)
#
# In this assignment you will build a heavy convolutional neural net (CNN) to solve Tiny ImageNet image classification. Try to achieve as high accuracy as possible.

# %% [markdown]
# ## Deliverables
#
# * This file,
# * a "checkpoint file" from `torch.save(model.state_dict(), ...)` that contains model's weights (which a TA should be able to load to verify your accuracy).
#
# ## Grading
#
# * 9 points for reproducible training code and a filled report below.
# * 12 points for building a network that gets above 20% accuracy.
# * 6.5 points for beating each of these milestones on the validation set:
#   * 25.0%
#   * 30.0%
#   * 32.5%
#   * 35.0%
#   * 37.5%
#   * 40.0%
#
# ## Restrictions
#
# * Don't use pretrained networks.
#
# ## Tips
#
# * One change at a time: never test several new things at once.
# * Google a lot.
# * Use GPU.
# * Use regularization: L2, batch normalization, dropout, data augmentation.
# * Use Tensorboard ([non-Colab](https://github.com/lanpa/tensorboardX) or [Colab](https://medium.com/@tommytao_54597/use-tensorboard-in-google-colab-16b4bb9812a6)) or a similar interactive tool for viewing progress.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch 
import torchvision
import torch.nn as nn
import pandas as pd
import os
from tqdm import tqdm_notebook as tqdm

from torch.utils.data import Dataset, DataLoader

# %matplotlib inline

# %%
import tiny_imagenet
tiny_imagenet.download(".")
# Out:
# ./tiny-imagenet-200 already exists, not downloading

# %%
path = "./tiny-imagenet-200"
folders = pd.read_csv(os.path.join(path, "wnids.txt"), header=None, names=["folders"])
f = list(folders['folders'])

# %% [markdown]
# Training and validation images are now in `tiny-imagenet-200/train` and `tiny-imagenet-200/val`.

# %% [markdown]
# ## Data

# %%
train_data = torchvision.datasets.ImageFolder('./tiny-imagenet-200/train/', 
                                              transform=torchvision.transforms.ToTensor())
val_data = torchvision.datasets.ImageFolder('./tiny-imagenet-200/val/', 
                                            transform=torchvision.transforms.ToTensor())


batch_size = 64

train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size, num_workers=2, shuffle=True, pin_memory=True)

val_loader = torch.utils.data.DataLoader(
    val_data, batch_size=batch_size, num_workers=2, shuffle=True, pin_memory=True)

# %% [markdown]
# ## Model

# %%
class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)

# %%
flat_model = nn.Sequential()

# reshape from "images" to flat vectors
flat_model.add_module('flatten', Flatten())

# dense "head"
flat_model.add_module('dense1', nn.Linear(3 * 64 * 64, 1064))
flat_model.add_module('dense2', nn.Linear(1064, 512))
flat_model.add_module('dropout0', nn.Dropout(0.05)) 
flat_model.add_module('dense3', nn.Linear(512, 256))
flat_model.add_module('dropout1', nn.Dropout(0.05))
flat_model.add_module('dense4', nn.Linear(256, 64))
flat_model.add_module('dropout2', nn.Dropout(0.05))
flat_model.add_module('dense1_relu', nn.ReLU())
flat_model.add_module('dense2_logits', nn.Linear(64, 200))

# %%
cnn = nn.Sequential(
    nn.Conv2d(in_channels=3, out_channels=2048, kernel_size=(3,3)),
    nn.Conv2d(in_channels=2048, out_channels=1024, kernel_size=(3,3)),
    nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=(3,3)),
    nn.ReLU(),
    nn.MaxPool2d((6,6)),
    nn.Conv2d(in_channels=6, out_channels=32, kernel_size=(20,20)),
    nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(20,20)),
    nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(20,20)),
    nn.Softmax(),
    Flatten(),
    nn.Linear(64, 256),
    nn.Softmax(),
    nn.Linear(256, 10),
    nn.Sigmoid(),
    nn.Dropout(0.5)
    
)

# cnn.cuda()

# %% [markdown]
# ## Loss

# %%
ce_loss = nn.CrossEntropyLoss()
nll_loss = nn.NLLLoss()

# %% [markdown]
# ## Optimizer

# %%
opt_cnn = torch.optim.Adam(cnn.parameters())
opt_flat = torch.optim.Adam(flat_model.parameters())

# %% [markdown]
# ## Training

# %%
train_loss = []
val_loss = []
val_accuracy = []
epochs = 25


import time

# %%
def onehotEncode(y):
    y_onehot = torch.zeros(y.shape[0], 200)
    y_onehot[ torch.arange(y.shape[0]), y] = 1
    return torch.LongTensor(y_onehot)

# %%
epochs = 1
for i in range(epochs):
    start_time = time.time()
    flat_model.train(True) # enable dropout / batch_norm training behavior
    for batch_idx, (x_batch, y_batch) in enumerate(tqdm(train_loader)):
        # train on batch
        activations = flat_model(x_batch)
        
#         loss = ce_loss(activations, onehotEncode(y_batch))
        loss = nll_loss(activations, y_batch)
        loss.backward()
        opt_flat.step()
        opt_flat.zero_grad()
        
        train_loss.append(loss.cpu().data.numpy())
        
    
#     flat_model.train(False) # disable dropout / use averages for batch_norm
#     for batch_idx, (x_batch, y_batch) in enumerate(tqdm(val_loader)):
#         activations = flat_model(x_batch)
#         loss = CE_loss(x_batch, y_batch)
#         val_loss.append(loss)
# Out:
# HBox(children=(IntProgress(value=0, max=1563), HTML(value='')))

# %%
train_loss
# Out:
# [array(-3420.2876, dtype=float32),
#  array(-7105.568, dtype=float32),
#  array(-6862.0815, dtype=float32),
#  array(-9555.198, dtype=float32),
#  array(-15532.112, dtype=float32),
#  array(-18336.94, dtype=float32),
#  array(-19861.146, dtype=float32),
#  array(-29989.078, dtype=float32),
#  array(-43000.867, dtype=float32),
#  array(-34782.55, dtype=float32),
#  array(-55339.918, dtype=float32),
#  array(-64847.074, dtype=float32),
#  array(-96655.23, dtype=float32),
#  array(-109585.055, dtype=float32),
#  array(-120643.59, dtype=float32),
#  array(-104602.1, dtype=float32),
#  array(-172613.17, dtype=float32),
#  array(-205282.55, dtype=float32),
#  array(-251104.39, dtype=float32),
#  array(-280038.62, dtype=float32),
#  array(-308397.72, dtype=float32),
#  array(-391618.44, dtype=float32),
#  array(-419643.12, dtype=float32),
#  array(-441578.16, dtype=float32),
#  array(-586499.56, dtype=float32),
#  array(-780570.7, dtype=float32),
#  array(-811777., dtype=float32),
#  array(-931149.75, dtype=float32),
#  array(-988923.8, dtype=float32),
#  array(-1153247., dtype=float32),
#  array(-1201470.1, dtype=float32),
#  array(-1504539.6, dtype=float32),
#  array(-1948074., dtype=float32),
#  array(-2013353.9, dtype=float32),
#  array(-2604579., dtype=float32),
#  array(-3030309.8, dtype=float32),
#  array(-3397392.8, dtype=float32),
#  array(-3726636., dtype=float32),
#  array(-4399784., dtype=float32),
#  array(-5317083., dtype=float32),
#  array(-5717036.5, dtype=float32),
#  array(-5325782.5, dtype=float32),
#  array(-6424523., dtype=float32),
#  array(-6792283., dtype=float32),
#  array(-7934668.5, dtype=float32),
#  array(-8831809., dtype=float32),
#  array(-11506116., dtype=float32),
#  array(-14600659., dtype=float32),
#  array(-13670612., dtype=float32),
#  array(-17330800., dtype=float32),
#  array(-16914158., dtype=float32),
#  array(-19198880., dtype=float32),
#  array(-20700362., dtype=float32),
#  array(-22270400., dtype=float32),
#  array(-27515138., dtype=float32),
#  array(-27231482., dtype=float32),
#  array(-31111896., dtype=float32),
#  array(-34849508., dtype=float32),
#  array(-37327828., dtype=float32),
#  array(-41929520., dtype=float32),
#  array(-48118870., dtype=float32),
#  array(-46986310., dtype=float32),
#  array(-62707636., dtype=float32),
#  array(-58264252., dtype=float32),
#  array(-66642940., dtype=float32),
#  array(-72970800., dtype=float32),
#  array(-79608150., dtype=float32),
#  array(-85397110., dtype=float32),
#  array(-1.0512211e+08, dtype=float32),
#  array(-1.1100202e+08, dtype=float32),
#  array(-1.1641562e+08, dtype=float32),
#  array(-1.1646019e+08, dtype=float32),
#  array(-1.20568104e+08, dtype=float32),
#  array(-1.5321104e+08, dtype=float32),
#  array(-1.5206126e+08, dtype=float32),
#  array(-1.6452797e+08, dtype=float32),
#  array(-1.8758008e+08, dtype=float32),
#  array(-2.0808832e+08, dtype=float32),
#  array(-2.2441128e+08, dtype=float32),
#  array(-2.514796e+08, dtype=float32),
#  array(-2.7781203e+08, dtype=float32),
#  array(-2.6701738e+08, dtype=float32),
#  array(-3.1236115e+08, dtype=float32),
#  array(-3.2099667e+08, dtype=float32),
#  array(-3.4540765e+08, dtype=float32),
#  array(-3.642623e+08, dtype=float32),
#  array(-4.4841546e+08, dtype=float32),
#  array(-4.5652032e+08, dtype=float32),
#  array(-4.520072e+08, dtype=float32),
#  array(-5.137405e+08, dtype=float32),
#  array(-5.1604784e+08, dtype=float32),
#  array(-5.4187834e+08, dtype=float32),
#  array(-6.298585e+08, dtype=float32),
#  array(-6.1398675e+08, dtype=float32),
#  array(-7.3362195e+08, dtype=float32),
#  array(-7.8361126e+08, dtype=float32),
#  array(-8.2319597e+08, dtype=float32),
#  array(-8.190669e+08, dtype=float32),
#  array(-9.386375e+08, dtype=float32),
#  array(-1.0846758e+09, dtype=float32),
#  array(-1.1059808e+09, dtype=float32),
#  array(-1.0874058e+09, dtype=float32),
#  array(-1.166784e+09, dtype=float32),
#  array(-1.2999245e+09, dtype=float32),
#  array(-1.3494234e+09, dtype=float32),
#  array(-1.3775953e+09, dtype=float32),
#  array(-1.6623855e+09, dtype=float32),
#  array(-1.5605956e+09, dtype=float32),
#  array(-1.7057723e+09, dtype=float32),
#  array(-1.7168813e+09, dtype=float32),
#  array(-1.7564205e+09, dtype=float32),
#  array(-1.9092764e+09, dtype=float32),
#  array(-2.2298237e+09, dtype=float32),
#  array(-2.275944e+09, dtype=float32),
#  array(-2.5498634e+09, dtype=float32),
#  array(-2.6007683e+09, dtype=float32),
#  array(-2.7019732e+09, dtype=float32),
#  array(-3.010544e+09, dtype=float32),
#  array(-3.0262892e+09, dtype=float32),
#  array(-3.0461962e+09, dtype=float32),
#  array(-3.0322138e+09, dtype=float32),
#  array(-3.2402913e+09, dtype=float32),
#  array(-3.5889226e+09, dtype=float32),
#  array(-4.1446935e+09, dtype=float32),
#  array(-3.9105618e+09, dtype=float32),
#  array(-4.2638241e+09, dtype=float32),
#  array(-4.5103247e+09, dtype=float32),
#  array(-4.861097e+09, dtype=float32),
#  array(-5.543203e+09, dtype=float32),
#  array(-5.2590904e+09, dtype=float32),
#  array(-5.5150536e+09, dtype=float32),
#  array(-5.6555873e+09, dtype=float32),
#  array(-6.373919e+09, dtype=float32),
#  array(-6.671213e+09, dtype=float32),
#  array(-6.7168e+09, dtype=float32),
#  array(-7.0849265e+09, dtype=float32),
#  array(-7.368948e+09, dtype=float32),
#  array(-7.3609774e+09, dtype=float32),
#  array(-8.2307927e+09, dtype=float32),
#  array(-8.5079613e+09, dtype=float32),
#  array(-8.617344e+09, dtype=float32),
#  array(-9.116684e+09, dtype=float32),
#  array(-9.146225e+09, dtype=float32),
#  array(-1.0085644e+10, dtype=float32),
#  array(-9.849924e+09, dtype=float32),
#  array(-1.1508076e+10, dtype=float32),
#  array(-1.1351838e+10, dtype=float32),
#  array(-1.1160578e+10, dtype=float32),
#  array(-1.2141336e+10, dtype=float32),
#  array(-1.2980905e+10, dtype=float32),
#  array(-1.3969662e+10, dtype=float32),
#  array(-1.4180899e+10, dtype=float32),
#  array(-1.4003375e+10, dtype=float32),
#  array(-1.5452496e+10, dtype=float32),
#  array(-1.6446592e+10, dtype=float32),
#  array(-1.6797325e+10, dtype=float32),
#  array(-1.7857796e+10, dtype=float32),
#  array(-1.8537222e+10, dtype=float32),
#  array(-1.8858138e+10, dtype=float32),
#  array(-1.961836e+10, dtype=float32),
#  array(-2.1685418e+10, dtype=float32),
#  array(-2.2618513e+10, dtype=float32),
#  array(-2.332463e+10, dtype=float32),
#  array(-2.305902e+10, dtype=float32),
#  array(-2.3517925e+10, dtype=float32),
#  array(-2.5374935e+10, dtype=float32),
#  array(-2.7262792e+10, dtype=float32),
#  array(-2.6565597e+10, dtype=float32),
#  array(-2.9675407e+10, dtype=float32),
#  array(-2.9026554e+10, dtype=float32),
#  array(-3.1646691e+10, dtype=float32),
#  array(-3.2647483e+10, dtype=float32),
#  array(-3.1951718e+10, dtype=float32),
#  array(-3.5330134e+10, dtype=float32),
#  array(-3.5104362e+10, dtype=float32),
#  array(-3.7175312e+10, dtype=float32),
#  array(-3.4800644e+10, dtype=float32),
#  array(-3.783989e+10, dtype=float32),
#  array(-4.1301225e+10, dtype=float32),
#  array(-4.1303036e+10, dtype=float32),
#  array(-4.529488e+10, dtype=float32),
#  array(-4.3011383e+10, dtype=float32),
#  array(-4.423774e+10, dtype=float32),
#  array(-5.354398e+10, dtype=float32),
#  array(-5.0155905e+10, dtype=float32),
#  array(-5.4660907e+10, dtype=float32),
#  array(-5.528632e+10, dtype=float32),
#  array(-5.5675113e+10, dtype=float32),
#  array(-5.300976e+10, dtype=float32),
#  array(-5.701296e+10, dtype=float32),
#  array(-6.038467e+10, dtype=float32),
#  array(-6.7746804e+10, dtype=float32),
#  array(-6.7101237e+10, dtype=float32),
#  array(-6.805859e+10, dtype=float32),
#  array(-6.893485e+10, dtype=float32),
#  array(-7.5783586e+10, dtype=float32),
#  array(-7.828312e+10, dtype=float32),
#  array(-7.796595e+10, dtype=float32),
#  array(-8.69981e+10, dtype=float32),
#  array(-8.511624e+10, dtype=float32),
#  array(-8.451447e+10, dtype=float32),
#  array(-9.099186e+10, dtype=float32),
#  array(-8.9395446e+10, dtype=float32),
#  array(-9.2087615e+10, dtype=float32),
#  array(-9.510366e+10, dtype=float32),
#  array(-9.9477e+10, dtype=float32),
#  array(-1.0753084e+11, dtype=float32),
#  array(-1.0428597e+11, dtype=float32),
#  array(-1.1306169e+11, dtype=float32),
#  array(-1.1476875e+11, dtype=float32),
#  array(-1.1568418e+11, dtype=float32),
#  array(-1.20489206e+11, dtype=float32),
#  array(-1.200915e+11, dtype=float32),
#  array(-1.2656806e+11, dtype=float32),
#  array(-1.31093004e+11, dtype=float32),
#  array(-1.24174926e+11, dtype=float32),
#  array(-1.4114469e+11, dtype=float32),
#  array(-1.3732551e+11, dtype=float32),
#  array(-1.425429e+11, dtype=float32),
#  array(-1.4754003e+11, dtype=float32),
#  array(-1.6719767e+11, dtype=float32),
#  array(-1.6618219e+11, dtype=float32),
#  array(-1.5771956e+11, dtype=float32),
#  array(-1.5665858e+11, dtype=float32),
#  array(-1.7140428e+11, dtype=float32),
#  array(-1.7660599e+11, dtype=float32),
#  array(-1.902623e+11, dtype=float32),
#  array(-1.718523e+11, dtype=float32),
#  array(-1.8320112e+11, dtype=float32),
#  array(-1.9961427e+11, dtype=float32),
#  array(-2.074224e+11, dtype=float32),
#  array(-2.1069255e+11, dtype=float32),
#  array(-2.090923e+11, dtype=float32),
#  array(-2.2922772e+11, dtype=float32),
#  array(-2.1238797e+11, dtype=float32),
#  array(-2.2345305e+11, dtype=float32),
#  array(-2.1983365e+11, dtype=float32),
#  array(-2.5082098e+11, dtype=float32),
#  array(-2.4810008e+11, dtype=float32),
#  array(-2.5013002e+11, dtype=float32),
#  array(-2.6670326e+11, dtype=float32),
#  array(-2.8803796e+11, dtype=float32),
#  array(-2.6747696e+11, dtype=float32),
#  array(-2.701144e+11, dtype=float32),
#  array(-2.807039e+11, dtype=float32),
#  array(-3.085684e+11, dtype=float32),
#  array(-2.9799727e+11, dtype=float32),
#  array(-3.2234062e+11, dtype=float32),
#  array(-2.8828448e+11, dtype=float32),
#  array(-3.3612225e+11, dtype=float32),
#  array(-3.3495902e+11, dtype=float32),
#  array(-3.4582508e+11, dtype=float32),
#  array(-3.5206808e+11, dtype=float32),
#  array(-3.7495466e+11, dtype=float32),
#  array(-3.6602583e+11, dtype=float32),
#  array(-3.6334322e+11, dtype=float32),
#  array(-3.590348e+11, dtype=float32),
#  array(-4.170137e+11, dtype=float32),
#  array(-4.0289763e+11, dtype=float32),
#  array(-4.3840668e+11, dtype=float32),
#  array(-4.1188717e+11, dtype=float32),
#  array(-4.303473e+11, dtype=float32),
#  array(-4.3000476e+11, dtype=float32),
#  array(-4.388483e+11, dtype=float32),
#  array(-4.6449472e+11, dtype=float32),
#  array(-4.8328527e+11, dtype=float32),
#  array(-4.991542e+11, dtype=float32),
#  array(-5.165912e+11, dtype=float32),
#  array(-5.1822405e+11, dtype=float32),
#  array(-5.216771e+11, dtype=float32),
#  array(-5.2342148e+11, dtype=float32),
#  array(-5.78808e+11, dtype=float32),
#  array(-5.27722e+11, dtype=float32),
#  array(-5.79785e+11, dtype=float32),
#  array(-5.8416307e+11, dtype=float32),
#  array(-5.8788033e+11, dtype=float32),
#  array(-6.002945e+11, dtype=float32),
#  array(-6.533756e+11, dtype=float32),
#  array(-6.516434e+11, dtype=float32),
#  array(-6.7499144e+11, dtype=float32),
#  array(-6.3404134e+11, dtype=float32),
#  array(-7.1767025e+11, dtype=float32),
#  array(-6.6991974e+11, dtype=float32),
#  array(-7.339214e+11, dtype=float32),
#  array(-7.140002e+11, dtype=float32),
#  array(-7.590639e+11, dtype=float32),
#  array(-8.0941724e+11, dtype=float32),
#  array(-7.3727345e+11, dtype=float32),
#  array(-7.777149e+11, dtype=float32),
#  array(-7.857497e+11, dtype=float32),
#  array(-8.602529e+11, dtype=float32),
#  array(-8.6100515e+11, dtype=float32),
#  array(-8.589652e+11, dtype=float32),
#  array(-8.643978e+11, dtype=float32),
#  array(-8.943008e+11, dtype=float32),
#  array(-9.5886075e+11, dtype=float32),
#  array(-9.219748e+11, dtype=float32),
#  array(-9.4910716e+11, dtype=float32),
#  array(-9.52315e+11, dtype=float32),
#  array(-9.563542e+11, dtype=float32),
#  array(-1.0057992e+12, dtype=float32),
#  array(-1.0749058e+12, dtype=float32),
#  array(-1.0602021e+12, dtype=float32),
#  array(-1.0385492e+12, dtype=float32),
#  array(-1.114506e+12, dtype=float32),
#  array(-1.1125954e+12, dtype=float32),
#  array(-1.1459672e+12, dtype=float32),
#  array(-1.148098e+12, dtype=float32),
#  array(-1.2192989e+12, dtype=float32),
#  array(-1.1435222e+12, dtype=float32),
#  array(-1.1657705e+12, dtype=float32),
#  array(-1.2542268e+12, dtype=float32),
#  array(-1.2393299e+12, dtype=float32),
#  array(-1.2596559e+12, dtype=float32),
#  array(-1.2333085e+12, dtype=float32),
#  array(-1.3107078e+12, dtype=float32),
#  array(-1.3486779e+12, dtype=float32),
#  array(-1.487954e+12, dtype=float32),
#  array(-1.3785378e+12, dtype=float32),
#  array(-1.4032172e+12, dtype=float32),
#  array(-1.5551955e+12, dtype=float32),
#  array(-1.48997e+12, dtype=float32),
#  array(-1.4854138e+12, dtype=float32),
#  array(-1.5783319e+12, dtype=float32),
#  array(-1.6445156e+12, dtype=float32),
#  array(-1.6139979e+12, dtype=float32),
#  array(-1.5910969e+12, dtype=float32),
#  array(-1.6915725e+12, dtype=float32),
#  array(-1.78433e+12, dtype=float32),
#  array(-1.7427574e+12, dtype=float32),
#  array(-1.7983064e+12, dtype=float32),
#  array(-1.7288743e+12, dtype=float32),
#  array(-1.8821326e+12, dtype=float32),
#  array(-1.8223204e+12, dtype=float32),
#  array(-1.8965677e+12, dtype=float32),
#  array(-1.974203e+12, dtype=float32),
#  array(-2.0292462e+12, dtype=float32),
#  array(-1.874744e+12, dtype=float32),
#  array(-1.8508787e+12, dtype=float32),
#  array(-1.9145051e+12, dtype=float32),
#  array(-2.241782e+12, dtype=float32),
#  array(-2.19949e+12, dtype=float32),
#  array(-2.2294262e+12, dtype=float32),
#  array(-2.1269828e+12, dtype=float32),
#  array(-2.260801e+12, dtype=float32),
#  array(-2.307315e+12, dtype=float32),
#  array(-2.2440014e+12, dtype=float32),
#  array(-2.375912e+12, dtype=float32),
#  array(-2.4407392e+12, dtype=float32),
#  array(-2.3733645e+12, dtype=float32),
#  array(-2.4797229e+12, dtype=float32),
#  array(-2.6716605e+12, dtype=float32),
#  array(-2.6076365e+12, dtype=float32),
#  array(-2.550173e+12, dtype=float32),
#  array(-2.5474834e+12, dtype=float32),
#  array(-2.7635307e+12, dtype=float32),
#  array(-2.6927523e+12, dtype=float32),
#  array(-2.5964435e+12, dtype=float32),
#  array(-2.848441e+12, dtype=float32),
#  array(-2.9092778e+12, dtype=float32),
#  array(-3.061494e+12, dtype=float32),
#  array(-2.896001e+12, dtype=float32),
#  array(-3.0591563e+12, dtype=float32),
#  array(-3.0145003e+12, dtype=float32),
#  array(-3.257804e+12, dtype=float32),
#  array(-3.1914989e+12, dtype=float32),
#  array(-3.1067383e+12, dtype=float32),
#  array(-3.2466034e+12, dtype=float32),
#  array(-3.3221223e+12, dtype=float32),
#  array(-3.500201e+12, dtype=float32),
#  array(-3.5677573e+12, dtype=float32),
#  array(-3.6984827e+12, dtype=float32),
#  array(-3.5206828e+12, dtype=float32),
#  array(-3.3337922e+12, dtype=float32),
#  array(-3.5451033e+12, dtype=float32),
#  array(-3.553903e+12, dtype=float32),
#  array(-3.5355047e+12, dtype=float32),
#  array(-4.0077505e+12, dtype=float32),
#  array(-3.71207e+12, dtype=float32),
#  array(-3.7222361e+12, dtype=float32),
#  array(-3.8032407e+12, dtype=float32),
#  array(-3.9416187e+12, dtype=float32),
#  array(-4.2961952e+12, dtype=float32),
#  array(-4.2086244e+12, dtype=float32),
#  array(-4.1787625e+12, dtype=float32),
#  array(-4.1889243e+12, dtype=float32),
#  array(-4.161125e+12, dtype=float32),
#  array(-4.21311e+12, dtype=float32),
#  array(-4.5145543e+12, dtype=float32),
#  array(-4.4820883e+12, dtype=float32),
#  array(-4.7182213e+12, dtype=float32),
#  array(-4.896743e+12, dtype=float32),
#  array(-4.4088746e+12, dtype=float32),
#  array(-4.6296785e+12, dtype=float32),
#  array(-5.0692494e+12, dtype=float32),
#  array(-4.7089446e+12, dtype=float32),
#  array(-5.1229937e+12, dtype=float32),
#  array(-5.273703e+12, dtype=float32),
#  array(-5.112374e+12, dtype=float32),
#  array(-5.582083e+12, dtype=float32),
#  array(-5.20571e+12, dtype=float32),
#  array(-5.578386e+12, dtype=float32),
#  array(-5.4274147e+12, dtype=float32),
#  array(-5.391607e+12, dtype=float32),
#  array(-5.453832e+12, dtype=float32),
#  array(-5.335176e+12, dtype=float32),
#  array(-5.8991937e+12, dtype=float32),
#  array(-5.685555e+12, dtype=float32),
#  array(-5.7355613e+12, dtype=float32),
#  array(-6.1161656e+12, dtype=float32),
#  array(-6.1966233e+12, dtype=float32),
#  array(-5.615297e+12, dtype=float32),
#  array(-6.213063e+12, dtype=float32),
#  array(-6.1935295e+12, dtype=float32),
#  array(-6.6149836e+12, dtype=float32),
#  array(-6.702128e+12, dtype=float32),
#  array(-6.460701e+12, dtype=float32),
#  array(-6.722013e+12, dtype=float32),
#  array(-6.4823875e+12, dtype=float32),
#  array(-6.6620196e+12, dtype=float32),
#  array(-6.9089855e+12, dtype=float32),
#  array(-6.6998433e+12, dtype=float32),
#  array(-7.62954e+12, dtype=float32),
#  array(-7.7981685e+12, dtype=float32),
#  array(-8.12626e+12, dtype=float32),
#  array(-7.366646e+12, dtype=float32),
#  array(-7.310494e+12, dtype=float32),
#  array(-7.758277e+12, dtype=float32),
#  array(-7.800421e+12, dtype=float32),
#  array(-8.000656e+12, dtype=float32),
#  array(-7.7422364e+12, dtype=float32),
#  array(-7.539238e+12, dtype=float32),
#  array(-8.2336054e+12, dtype=float32),
#  array(-8.3528673e+12, dtype=float32),
#  array(-8.039505e+12, dtype=float32),
#  array(-8.914559e+12, dtype=float32),
#  array(-8.897603e+12, dtype=float32),
#  array(-8.749631e+12, dtype=float32),
#  array(-8.789864e+12, dtype=float32),
#  array(-9.125456e+12, dtype=float32),
#  array(-8.918986e+12, dtype=float32),
#  array(-9.211213e+12, dtype=float32),
#  array(-9.407836e+12, dtype=float32),
#  array(-9.494299e+12, dtype=float32),
#  array(-9.665663e+12, dtype=float32),
#  array(-9.932906e+12, dtype=float32),
#  array(-9.897518e+12, dtype=float32),
#  array(-9.984816e+12, dtype=float32),
#  array(-9.704065e+12, dtype=float32),
#  array(-9.42876e+12, dtype=float32),
#  array(-1.0317152e+13, dtype=float32),
#  array(-1.050054e+13, dtype=float32),
#  array(-1.0552939e+13, dtype=float32),
#  array(-1.0700182e+13, dtype=float32),
#  array(-1.0611548e+13, dtype=float32),
#  array(-1.0749806e+13, dtype=float32),
#  array(-1.1100494e+13, dtype=float32),
#  array(-1.105474e+13, dtype=float32),
#  array(-1.0898706e+13, dtype=float32),
#  array(-1.1654879e+13, dtype=float32),
#  array(-1.0971129e+13, dtype=float32),
#  array(-1.1663645e+13, dtype=float32),
#  array(-1.1686173e+13, dtype=float32),
#  array(-1.25226e+13, dtype=float32),
#  array(-1.2528877e+13, dtype=float32),
#  array(-1.2663123e+13, dtype=float32),
#  array(-1.214291e+13, dtype=float32),
#  array(-1.2913722e+13, dtype=float32),
#  array(-1.2278096e+13, dtype=float32),
#  array(-1.3204544e+13, dtype=float32),
#  array(-1.2794246e+13, dtype=float32),
#  array(-1.3683204e+13, dtype=float32),
#  array(-1.3298612e+13, dtype=float32),
#  array(-1.3584651e+13, dtype=float32),
#  array(-1.3516471e+13, dtype=float32),
#  array(-1.3500187e+13, dtype=float32),
#  array(-1.4295341e+13, dtype=float32),
#  array(-1.3828119e+13, dtype=float32),
#  array(-1.3773432e+13, dtype=float32),
#  array(-1.4040229e+13, dtype=float32),
#  array(-1.4645073e+13, dtype=float32),
#  array(-1.5339215e+13, dtype=float32),
#  array(-1.4729121e+13, dtype=float32),
#  array(-1.532162e+13, dtype=float32),
#  array(-1.5637297e+13, dtype=float32),
#  array(-1.5179586e+13, dtype=float32),
#  array(-1.550523e+13, dtype=float32),
#  array(-1.647042e+13, dtype=float32),
#  array(-1.6191152e+13, dtype=float32),
#  array(-1.6083473e+13, dtype=float32),
#  array(-1.6521234e+13, dtype=float32),
#  array(-1.7350946e+13, dtype=float32),
#  array(-1.7035647e+13, dtype=float32),
#  array(-1.7656223e+13, dtype=float32),
#  array(-1.6623735e+13, dtype=float32),
#  array(-1.7929546e+13, dtype=float32),
#  array(-1.738471e+13, dtype=float32),
#  array(-1.7264519e+13, dtype=float32),
#  array(-1.8466747e+13, dtype=float32),
#  array(-1.8814794e+13, dtype=float32),
#  array(-1.8972668e+13, dtype=float32),
#  array(-1.8825978e+13, dtype=float32),
#  array(-1.7860305e+13, dtype=float32),
#  array(-2.015377e+13, dtype=float32),
#  array(-1.9796937e+13, dtype=float32),
#  array(-1.7755558e+13, dtype=float32),
#  array(-1.8810598e+13, dtype=float32),
#  array(-1.8849603e+13, dtype=float32),
#  array(-2.0825216e+13, dtype=float32),
#  array(-2.0681064e+13, dtype=float32),
#  array(-2.2309805e+13, dtype=float32),
#  array(-1.9891936e+13, dtype=float32),
#  array(-2.0335315e+13, dtype=float32),
#  array(-2.1062373e+13, dtype=float32),
#  array(-2.0828985e+13, dtype=float32),
#  array(-2.1083426e+13, dtype=float32),
#  array(-2.1692166e+13, dtype=float32),
#  array(-2.0970847e+13, dtype=float32),
#  array(-2.2241943e+13, dtype=float32),
#  array(-2.2963661e+13, dtype=float32),
#  array(-2.3592398e+13, dtype=float32),
#  array(-2.2740977e+13, dtype=float32),
#  array(-2.375872e+13, dtype=float32),
#  array(-2.2944623e+13, dtype=float32),
#  array(-2.417237e+13, dtype=float32),
#  array(-2.5243836e+13, dtype=float32),
#  array(-2.454302e+13, dtype=float32),
#  array(-2.3898817e+13, dtype=float32),
#  array(-2.4301787e+13, dtype=float32),
#  array(-2.4146354e+13, dtype=float32),
#  array(-2.6984166e+13, dtype=float32),
#  array(-2.6109236e+13, dtype=float32),
#  array(-2.4253427e+13, dtype=float32),
#  array(-2.6343767e+13, dtype=float32),
#  array(-2.5841237e+13, dtype=float32),
#  array(-2.7860601e+13, dtype=float32),
#  array(-2.734473e+13, dtype=float32),
#  array(-2.5863553e+13, dtype=float32),
#  array(-2.810835e+13, dtype=float32),
#  array(-2.7086115e+13, dtype=float32),
#  array(-2.706938e+13, dtype=float32),
#  array(-2.8689184e+13, dtype=float32),
#  array(-3.0265836e+13, dtype=float32),
#  array(-2.8852986e+13, dtype=float32),
#  array(-2.8518545e+13, dtype=float32),
#  array(-2.9680931e+13, dtype=float32),
#  array(-3.0631975e+13, dtype=float32),
#  array(-2.8864508e+13, dtype=float32),
#  array(-2.9746478e+13, dtype=float32),
#  array(-2.9953557e+13, dtype=float32),
#  array(-3.092659e+13, dtype=float32),
#  array(-3.1464003e+13, dtype=float32),
#  array(-3.2032424e+13, dtype=float32),
#  array(-3.1559707e+13, dtype=float32),
#  array(-3.4275506e+13, dtype=float32),
#  array(-3.105952e+13, dtype=float32),
#  array(-3.2519271e+13, dtype=float32),
#  array(-3.3440416e+13, dtype=float32),
#  array(-3.212014e+13, dtype=float32),
#  array(-3.1508742e+13, dtype=float32),
#  array(-3.4868317e+13, dtype=float32),
#  array(-3.4754729e+13, dtype=float32),
#  array(-3.567104e+13, dtype=float32),
#  array(-3.662649e+13, dtype=float32),
#  array(-3.3844726e+13, dtype=float32),
#  array(-3.4016426e+13, dtype=float32),
#  array(-3.6978276e+13, dtype=float32),
#  array(-3.7393437e+13, dtype=float32),
#  array(-3.4998745e+13, dtype=float32),
#  array(-3.566346e+13, dtype=float32),
#  array(-3.7805808e+13, dtype=float32),
#  array(-3.733111e+13, dtype=float32),
#  array(-3.8905563e+13, dtype=float32),
#  array(-4.0162344e+13, dtype=float32),
#  array(-4.169612e+13, dtype=float32),
#  array(-3.7267914e+13, dtype=float32),
#  array(-3.8598263e+13, dtype=float32),
#  array(-4.3232793e+13, dtype=float32),
#  array(-4.1509756e+13, dtype=float32),
#  array(-3.9211944e+13, dtype=float32),
#  array(-4.218906e+13, dtype=float32),
#  array(-4.1945313e+13, dtype=float32),
#  array(-4.363078e+13, dtype=float32),
#  array(-4.275712e+13, dtype=float32),
#  array(-4.4686815e+13, dtype=float32),
#  array(-4.5212517e+13, dtype=float32),
#  array(-4.166676e+13, dtype=float32),
#  array(-4.2705015e+13, dtype=float32),
#  array(-4.497614e+13, dtype=float32),
#  array(-4.7064763e+13, dtype=float32),
#  array(-4.2642818e+13, dtype=float32),
#  array(-4.629786e+13, dtype=float32),
#  array(-4.6923583e+13, dtype=float32),
#  array(-4.5807798e+13, dtype=float32),
#  array(-4.826968e+13, dtype=float32),
#  array(-4.949279e+13, dtype=float32),
#  array(-4.853134e+13, dtype=float32),
#  array(-5.0138366e+13, dtype=float32),
#  array(-4.573446e+13, dtype=float32),
#  array(-4.7802294e+13, dtype=float32),
#  array(-4.844338e+13, dtype=float32),
#  array(-4.9436747e+13, dtype=float32),
#  array(-4.678297e+13, dtype=float32),
#  array(-4.937609e+13, dtype=float32),
#  array(-5.1401003e+13, dtype=float32),
#  array(-5.100425e+13, dtype=float32),
#  array(-5.4589286e+13, dtype=float32),
#  array(-5.1871494e+13, dtype=float32),
#  array(-5.3800753e+13, dtype=float32),
#  array(-5.6901824e+13, dtype=float32),
#  array(-5.2099686e+13, dtype=float32),
#  array(-5.080366e+13, dtype=float32),
#  array(-5.92456e+13, dtype=float32),
#  array(-5.607652e+13, dtype=float32),
#  array(-5.695697e+13, dtype=float32),
#  array(-5.2836184e+13, dtype=float32),
#  array(-5.6623788e+13, dtype=float32),
#  array(-5.7045554e+13, dtype=float32),
#  array(-5.947716e+13, dtype=float32),
#  array(-5.5783178e+13, dtype=float32),
#  array(-6.033051e+13, dtype=float32),
#  array(-5.870544e+13, dtype=float32),
#  array(-6.1362655e+13, dtype=float32),
#  array(-6.214935e+13, dtype=float32),
#  array(-6.188623e+13, dtype=float32),
#  array(-6.398182e+13, dtype=float32),
#  array(-6.0471957e+13, dtype=float32),
#  array(-5.9686766e+13, dtype=float32),
#  array(-6.344132e+13, dtype=float32),
#  array(-6.1633238e+13, dtype=float32),
#  array(-6.9459704e+13, dtype=float32),
#  array(-6.248173e+13, dtype=float32),
#  array(-6.4653044e+13, dtype=float32),
#  array(-6.46526e+13, dtype=float32),
#  array(-6.557147e+13, dtype=float32),
#  array(-6.9648037e+13, dtype=float32),
#  array(-6.20166e+13, dtype=float32),
#  array(-6.6891356e+13, dtype=float32),
#  array(-6.5963915e+13, dtype=float32),
#  array(-6.335986e+13, dtype=float32),
#  array(-6.757751e+13, dtype=float32),
#  array(-7.264843e+13, dtype=float32),
#  array(-6.9892745e+13, dtype=float32),
#  array(-6.9650277e+13, dtype=float32),
#  array(-7.200842e+13, dtype=float32),
#  array(-6.9784645e+13, dtype=float32),
#  array(-7.245362e+13, dtype=float32),
#  array(-7.0170916e+13, dtype=float32),
#  array(-7.575588e+13, dtype=float32),
#  array(-7.950952e+13, dtype=float32),
#  array(-7.2686835e+13, dtype=float32),
#  array(-7.841193e+13, dtype=float32),
#  array(-7.620404e+13, dtype=float32),
#  array(-7.595392e+13, dtype=float32),
#  array(-7.744697e+13, dtype=float32),
#  array(-8.045697e+13, dtype=float32),
#  array(-8.52224e+13, dtype=float32),
#  array(-8.151517e+13, dtype=float32),
#  array(-8.11938e+13, dtype=float32),
#  array(-7.809465e+13, dtype=float32),
#  array(-7.777853e+13, dtype=float32),
#  array(-7.866418e+13, dtype=float32),
#  array(-8.597488e+13, dtype=float32),
#  array(-8.558434e+13, dtype=float32),
#  array(-7.908713e+13, dtype=float32),
#  array(-8.6196915e+13, dtype=float32),
#  array(-9.016049e+13, dtype=float32),
#  array(-8.7636736e+13, dtype=float32),
#  array(-8.497275e+13, dtype=float32),
#  array(-8.880154e+13, dtype=float32),
#  array(-8.982429e+13, dtype=float32),
#  array(-8.677579e+13, dtype=float32),
#  array(-8.9536026e+13, dtype=float32),
#  array(-8.868548e+13, dtype=float32),
#  array(-9.259459e+13, dtype=float32),
#  array(-9.197715e+13, dtype=float32),
#  array(-9.143771e+13, dtype=float32),
#  array(-9.562555e+13, dtype=float32),
#  array(-9.33598e+13, dtype=float32),
#  array(-9.425092e+13, dtype=float32),
#  array(-9.763735e+13, dtype=float32),
#  array(-9.135478e+13, dtype=float32),
#  array(-1.03479545e+14, dtype=float32),
#  array(-9.0912445e+13, dtype=float32),
#  array(-9.071573e+13, dtype=float32),
#  array(-9.633274e+13, dtype=float32),
#  array(-1.0406972e+14, dtype=float32),
#  array(-9.629598e+13, dtype=float32),
#  array(-9.831385e+13, dtype=float32),
#  array(-1.01942e+14, dtype=float32),
#  array(-9.9828864e+13, dtype=float32),
#  array(-9.856637e+13, dtype=float32),
#  array(-1.0505373e+14, dtype=float32),
#  array(-1.0850117e+14, dtype=float32),
#  array(-1.1453927e+14, dtype=float32),
#  array(-1.0945074e+14, dtype=float32),
#  array(-1.1003838e+14, dtype=float32),
#  array(-1.0558846e+14, dtype=float32),
#  array(-1.0911064e+14, dtype=float32),
#  array(-1.0364651e+14, dtype=float32),
#  array(-1.128701e+14, dtype=float32),
#  array(-1.1045702e+14, dtype=float32),
#  array(-1.1270971e+14, dtype=float32),
#  array(-1.15897805e+14, dtype=float32),
#  array(-1.1021468e+14, dtype=float32),
#  array(-1.1218176e+14, dtype=float32),
#  array(-1.10895326e+14, dtype=float32),
#  array(-1.1799549e+14, dtype=float32),
#  array(-1.16967755e+14, dtype=float32),
#  array(-1.2329911e+14, dtype=float32),
#  array(-1.151034e+14, dtype=float32),
#  array(-1.1504565e+14, dtype=float32),
#  array(-1.2061448e+14, dtype=float32),
#  array(-1.1591399e+14, dtype=float32),
#  array(-1.3487555e+14, dtype=float32),
#  array(-1.2385323e+14, dtype=float32),
#  array(-1.2181958e+14, dtype=float32),
#  array(-1.22736895e+14, dtype=float32),
#  array(-1.3201233e+14, dtype=float32),
#  array(-1.265612e+14, dtype=float32),
#  array(-1.26708196e+14, dtype=float32),
#  array(-1.2853938e+14, dtype=float32),
#  array(-1.2607402e+14, dtype=float32),
#  array(-1.2954389e+14, dtype=float32),
#  array(-1.29940956e+14, dtype=float32),
#  array(-1.26473625e+14, dtype=float32),
#  array(-1.36727776e+14, dtype=float32),
#  array(-1.30463985e+14, dtype=float32),
#  array(-1.200333e+14, dtype=float32),
#  array(-1.4710946e+14, dtype=float32),
#  array(-1.4241149e+14, dtype=float32),
#  array(-1.2684762e+14, dtype=float32),
#  array(-1.365467e+14, dtype=float32),
#  array(-1.4203029e+14, dtype=float32),
#  array(-1.4592363e+14, dtype=float32),
#  array(-1.4465514e+14, dtype=float32),
#  array(-1.4933814e+14, dtype=float32),
#  array(-1.4435466e+14, dtype=float32),
#  array(-1.4498055e+14, dtype=float32),
#  array(-1.4109634e+14, dtype=float32),
#  array(-1.493935e+14, dtype=float32),
#  array(-1.4463972e+14, dtype=float32),
#  array(-1.457242e+14, dtype=float32),
#  array(-1.5805642e+14, dtype=float32),
#  array(-1.4417088e+14, dtype=float32),
#  array(-1.4632866e+14, dtype=float32),
#  array(-1.4970114e+14, dtype=float32),
#  array(-1.5373297e+14, dtype=float32),
#  array(-1.4925441e+14, dtype=float32),
#  array(-1.591017e+14, dtype=float32),
#  array(-1.572287e+14, dtype=float32),
#  array(-1.5430103e+14, dtype=float32),
#  array(-1.5842111e+14, dtype=float32),
#  array(-1.594479e+14, dtype=float32),
#  array(-1.7351945e+14, dtype=float32),
#  array(-1.7627774e+14, dtype=float32),
#  array(-1.6467596e+14, dtype=float32),
#  array(-1.5509375e+14, dtype=float32),
#  array(-1.5360375e+14, dtype=float32),
#  array(-1.7288461e+14, dtype=float32),
#  array(-1.6568118e+14, dtype=float32),
#  array(-1.6091023e+14, dtype=float32),
#  array(-1.7246082e+14, dtype=float32),
#  array(-1.7224594e+14, dtype=float32),
#  array(-1.7508515e+14, dtype=float32),
#  array(-1.6862085e+14, dtype=float32),
#  array(-1.7413353e+14, dtype=float32),
#  array(-1.7641833e+14, dtype=float32),
#  array(-1.789231e+14, dtype=float32),
#  array(-1.8474156e+14, dtype=float32),
#  array(-1.896263e+14, dtype=float32),
#  array(-1.8532235e+14, dtype=float32),
#  array(-1.7461208e+14, dtype=float32),
#  array(-1.7797757e+14, dtype=float32),
#  array(-1.8600475e+14, dtype=float32),
#  array(-1.7628598e+14, dtype=float32),
#  array(-1.9156812e+14, dtype=float32),
#  array(-1.7152942e+14, dtype=float32),
#  array(-1.9350121e+14, dtype=float32),
#  array(-1.9100522e+14, dtype=float32),
#  array(-1.9525819e+14, dtype=float32),
#  array(-1.9515268e+14, dtype=float32),
#  array(-1.9727295e+14, dtype=float32),
#  array(-1.9187228e+14, dtype=float32),
#  array(-2.0877745e+14, dtype=float32),
#  array(-1.9382268e+14, dtype=float32),
#  array(-2.0395603e+14, dtype=float32),
#  array(-1.9395572e+14, dtype=float32),
#  array(-1.9589042e+14, dtype=float32),
#  array(-2.0844305e+14, dtype=float32),
#  array(-1.9760282e+14, dtype=float32),
#  array(-2.1005012e+14, dtype=float32),
#  array(-2.0419216e+14, dtype=float32),
#  array(-1.9078808e+14, dtype=float32),
#  array(-2.1531012e+14, dtype=float32),
#  array(-2.0464888e+14, dtype=float32),
#  array(-2.1995076e+14, dtype=float32),
#  array(-2.1675393e+14, dtype=float32),
#  array(-2.2413109e+14, dtype=float32),
#  array(-2.2625232e+14, dtype=float32),
#  array(-2.2496144e+14, dtype=float32),
#  array(-2.212032e+14, dtype=float32),
#  array(-2.1549567e+14, dtype=float32),
#  array(-2.3305667e+14, dtype=float32),
#  array(-2.2070832e+14, dtype=float32),
#  array(-2.2852056e+14, dtype=float32),
#  array(-2.2404687e+14, dtype=float32),
#  array(-2.2495098e+14, dtype=float32),
#  array(-2.2342244e+14, dtype=float32),
#  array(-2.2234138e+14, dtype=float32),
#  array(-2.3361354e+14, dtype=float32),
#  array(-2.2646908e+14, dtype=float32),
#  array(-2.3147164e+14, dtype=float32),
#  array(-2.4688992e+14, dtype=float32),
#  array(-2.4298222e+14, dtype=float32),
#  array(-2.3673254e+14, dtype=float32),
#  array(-2.2647339e+14, dtype=float32),
#  array(-2.4006673e+14, dtype=float32),
#  array(-2.4336078e+14, dtype=float32),
#  array(-2.3791721e+14, dtype=float32),
#  array(-2.5465569e+14, dtype=float32),
#  array(-2.6107739e+14, dtype=float32),
#  array(-2.485343e+14, dtype=float32),
#  array(-2.5598295e+14, dtype=float32),
#  array(-2.4863546e+14, dtype=float32),
#  array(-2.4371825e+14, dtype=float32),
#  array(-2.6345792e+14, dtype=float32),
#  array(-2.6603383e+14, dtype=float32),
#  array(-2.5658499e+14, dtype=float32),
#  array(-2.4509494e+14, dtype=float32),
#  array(-2.6677406e+14, dtype=float32),
#  array(-2.6844963e+14, dtype=float32),
#  array(-2.609763e+14, dtype=float32),
#  array(-2.634744e+14, dtype=float32),
#  array(-2.7230487e+14, dtype=float32),
#  array(-2.7204113e+14, dtype=float32),
#  array(-2.6715032e+14, dtype=float32),
#  array(-2.7820349e+14, dtype=float32),
#  array(-2.697014e+14, dtype=float32),
#  array(-2.978782e+14, dtype=float32),
#  array(-2.82984e+14, dtype=float32),
#  array(-2.8956357e+14, dtype=float32),
#  array(-2.7486032e+14, dtype=float32),
#  array(-2.8300368e+14, dtype=float32),
#  array(-2.8190998e+14, dtype=float32),
#  array(-2.9915716e+14, dtype=float32),
#  array(-2.8526425e+14, dtype=float32),
#  array(-3.064589e+14, dtype=float32),
#  array(-2.9721848e+14, dtype=float32),
#  array(-2.8688308e+14, dtype=float32),
#  array(-2.9412956e+14, dtype=float32),
#  array(-2.8424322e+14, dtype=float32),
#  array(-3.0062637e+14, dtype=float32),
#  array(-2.931787e+14, dtype=float32),
#  array(-2.9912746e+14, dtype=float32),
#  array(-3.18945e+14, dtype=float32),
#  array(-3.115173e+14, dtype=float32),
#  array(-3.1996355e+14, dtype=float32),
#  array(-3.0527812e+14, dtype=float32),
#  array(-3.0843952e+14, dtype=float32),
#  array(-3.1409562e+14, dtype=float32),
#  array(-3.0961436e+14, dtype=float32),
#  array(-3.0294196e+14, dtype=float32),
#  array(-3.086881e+14, dtype=float32),
#  array(-3.178971e+14, dtype=float32),
#  array(-3.0929147e+14, dtype=float32),
#  array(-3.0439322e+14, dtype=float32),
#  array(-3.05818e+14, dtype=float32),
#  array(-3.4084813e+14, dtype=float32),
#  array(-3.4868333e+14, dtype=float32),
#  array(-3.119288e+14, dtype=float32),
#  array(-3.3316132e+14, dtype=float32),
#  array(-3.6402026e+14, dtype=float32),
#  array(-3.2756944e+14, dtype=float32),
#  array(-3.2378e+14, dtype=float32),
#  array(-3.5384873e+14, dtype=float32),
#  array(-3.3273675e+14, dtype=float32),
#  array(-3.584306e+14, dtype=float32),
#  array(-3.6610714e+14, dtype=float32),
#  array(-3.4326147e+14, dtype=float32),
#  array(-3.2503863e+14, dtype=float32),
#  array(-3.4649615e+14, dtype=float32),
#  array(-3.5459267e+14, dtype=float32),
#  array(-3.4645585e+14, dtype=float32),
#  array(-3.6555477e+14, dtype=float32),
#  array(-3.7069698e+14, dtype=float32),
#  array(-3.7644207e+14, dtype=float32),
#  array(-3.741066e+14, dtype=float32),
#  array(-3.720679e+14, dtype=float32),
#  array(-3.7501457e+14, dtype=float32),
#  array(-3.52607e+14, dtype=float32),
#  array(-3.8423405e+14, dtype=float32),
#  array(-3.6356962e+14, dtype=float32),
#  array(-3.7856617e+14, dtype=float32),
#  array(-3.7427536e+14, dtype=float32),
#  array(-4.0466085e+14, dtype=float32),
#  array(-3.7908754e+14, dtype=float32),
#  array(-3.9348826e+14, dtype=float32),
#  array(-3.7702907e+14, dtype=float32),
#  array(-3.8916242e+14, dtype=float32),
#  array(-3.981393e+14, dtype=float32),
#  array(-4.018343e+14, dtype=float32),
#  array(-4.326926e+14, dtype=float32),
#  array(-3.9313527e+14, dtype=float32),
#  array(-4.3301444e+14, dtype=float32),
#  array(-3.7774455e+14, dtype=float32),
#  array(-3.9111375e+14, dtype=float32),
#  array(-4.1946687e+14, dtype=float32),
#  array(-4.130449e+14, dtype=float32),
#  array(-4.188175e+14, dtype=float32),
#  array(-3.8433454e+14, dtype=float32),
#  array(-4.273224e+14, dtype=float32),
#  array(-4.184705e+14, dtype=float32),
#  array(-4.1281024e+14, dtype=float32),
#  array(-4.1016696e+14, dtype=float32),
#  array(-4.207153e+14, dtype=float32),
#  array(-4.5771185e+14, dtype=float32),
#  array(-4.2812617e+14, dtype=float32),
#  array(-4.319495e+14, dtype=float32),
#  array(-4.2117614e+14, dtype=float32),
#  array(-4.431602e+14, dtype=float32),
#  array(-4.5513483e+14, dtype=float32),
#  array(-4.6319672e+14, dtype=float32),
#  array(-4.7787017e+14, dtype=float32),
#  array(-4.3285338e+14, dtype=float32),
#  array(-4.6113024e+14, dtype=float32),
#  array(-4.3808364e+14, dtype=float32),
#  array(-4.4323888e+14, dtype=float32),
#  array(-4.7053504e+14, dtype=float32),
#  array(-4.768018e+14, dtype=float32),
#  array(-4.7225477e+14, dtype=float32),
#  array(-4.6481995e+14, dtype=float32),
#  array(-4.8374186e+14, dtype=float32),
#  array(-5.1275413e+14, dtype=float32),
#  array(-4.7899052e+14, dtype=float32),
#  array(-4.7818387e+14, dtype=float32),
#  array(-4.8139466e+14, dtype=float32),
#  array(-4.9198703e+14, dtype=float32),
#  array(-4.6813902e+14, dtype=float32),
#  array(-5.186844e+14, dtype=float32),
#  array(-4.9614623e+14, dtype=float32),
#  array(-4.9032803e+14, dtype=float32),
#  array(-4.9485865e+14, dtype=float32),
#  array(-4.7366554e+14, dtype=float32),
#  array(-5.104204e+14, dtype=float32),
#  array(-4.8611608e+14, dtype=float32),
#  array(-5.0242655e+14, dtype=float32),
#  array(-4.8253196e+14, dtype=float32),
#  array(-5.3368703e+14, dtype=float32),
#  array(-5.02433e+14, dtype=float32),
#  array(-5.1698182e+14, dtype=float32),
#  array(-5.5458698e+14, dtype=float32),
#  array(-5.44013e+14, dtype=float32),
#  array(-5.370503e+14, dtype=float32),
#  array(-5.5273914e+14, dtype=float32),
#  array(-5.0909177e+14, dtype=float32),
#  array(-5.583952e+14, dtype=float32),
#  array(-5.301707e+14, dtype=float32),
#  array(-5.4062958e+14, dtype=float32),
#  array(-5.191725e+14, dtype=float32),
#  array(-5.434638e+14, dtype=float32),
#  array(-5.49385e+14, dtype=float32),
#  array(-5.5959488e+14, dtype=float32),
#  array(-5.3494955e+14, dtype=float32),
#  array(-5.6319886e+14, dtype=float32),
#  array(-5.742311e+14, dtype=float32),
#  array(-5.543211e+14, dtype=float32),
#  array(-5.6925456e+14, dtype=float32),
#  array(-5.702542e+14, dtype=float32),
#  array(-5.754085e+14, dtype=float32),
#  array(-5.784408e+14, dtype=float32),
#  array(-5.238807e+14, dtype=float32),
#  array(-5.5679577e+14, dtype=float32),
#  array(-5.8608674e+14, dtype=float32),
#  array(-5.785898e+14, dtype=float32),
#  array(-6.131606e+14, dtype=float32),
#  array(-5.845324e+14, dtype=float32),
#  array(-6.017277e+14, dtype=float32),
#  array(-5.7028395e+14, dtype=float32),
#  array(-5.756536e+14, dtype=float32),
#  array(-5.8491824e+14, dtype=float32),
#  array(-6.100389e+14, dtype=float32),
#  array(-6.418645e+14, dtype=float32),
#  array(-5.6999484e+14, dtype=float32),
#  array(-6.32468e+14, dtype=float32),
#  array(-6.194253e+14, dtype=float32),
#  array(-6.0353934e+14, dtype=float32),
#  array(-6.388186e+14, dtype=float32),
#  array(-6.66591e+14, dtype=float32),
#  array(-6.6408804e+14, dtype=float32),
#  array(-6.4657787e+14, dtype=float32),
#  array(-6.258591e+14, dtype=float32),
#  array(-6.2896984e+14, dtype=float32),
#  array(-6.240917e+14, dtype=float32),
#  array(-6.534582e+14, dtype=float32),
#  array(-6.583019e+14, dtype=float32),
#  array(-6.049609e+14, dtype=float32),
#  array(-6.151988e+14, dtype=float32),
#  array(-6.6069744e+14, dtype=float32),
#  array(-6.689029e+14, dtype=float32),
#  ...]

# %%
torch.arange(4)
# Out:
# tensor([0, 1, 2, 3])

# %% [markdown]
# When everything is done, please compute accuracy on the validation set and report it below.

# %%
val_accuracy = # Your code here
print("Validation accuracy: %.2f%%" % (val_accuracy * 100))

# %% [markdown]
# # Report
#
# Below, please mention
#
# * a brief history of tweaks and improvements;
# * what is the final architecture and why?
# * what is the training method (batch size, optimization algorithm, ...) and why?
# * Any regularization and other techniques applied and their effects;
#
# The reference format is:
#
# *"I have analyzed these and these articles|sources|blog posts, tried that and that to adapt them to my problem and the conclusions are such and such".*

# %%
# class TinyImagaNet(Dataset):
#     def __init__(self, path):
#         self.root_dir = path
#         self.train_dir = os.path.join(path, "train")
#         self.val_dir = os.path.join(path, "val")
#         self.test_dir = os.path.join(path, "test", "images")
#         self.labels = pd.read_csv(os.path.join(path, 'words.txt'), sep='\t', header=None, names=['code', 'label'])
#         self.folders = pd.read_csv(os.path.join(path, "wnids.txt"), header=None, names=["folders"])
#     def __getitem__(self, folder, idx):
#         pass
